# %%
import boto3
import json
import base64
import requests
import time
import pandas as pd

# %%
# load client and resource
sd_session = boto3.session.Session(profile_name='smart-dyspnea')
s3_client = sd_session.client('s3')
transcribe_client = sd_session.client('transcribe')

# %%
with open('./data/ml_data.json', 'r') as f:
    data = json.loads(f.read())

# %%
audio = base64.b64decode(data[76]['audio']['data'].encode('utf-8'))

# %%
type(data[76]['audio']['data'])
# Out:
# str

# %%
with open('./data/audio.mp3', 'wb') as f:
    f.write(audio)

# %%
response = s3_client.upload_file(Bucket='sd-test-ml', Key='audios/audio.mp3', Filename="./data/audio.mp3")

# %%
response = transcribe_client.start_transcription_job(
    TranscriptionJobName='test-clase-1',
    LanguageCode='es-ES',
    MediaFormat='mp3',
    Media={
        'MediaFileUri': f"s3://sd-test-ml/audios/audio.mp3"
    },
#    Settings={
#        'ShowAlternatives': True,
#        'MaxAlternatives': 3,
#        'VocabularyFilterName': 'string',
#        'VocabularyFilterMethod': 'remove'|'mask'
#    },
)

# %%
response
# Out:
# {'TranscriptionJob': {'TranscriptionJobName': 'test-clase-1',
#   'TranscriptionJobStatus': 'IN_PROGRESS',
#   'LanguageCode': 'es-ES',
#   'MediaFormat': 'mp3',
#   'Media': {'MediaFileUri': 's3://sd-test-ml/audios/audio.mp3'},
#   'StartTime': datetime.datetime(2021, 3, 17, 18, 22, 4, 47000, tzinfo=tzlocal()),
#   'CreationTime': datetime.datetime(2021, 3, 17, 18, 22, 4, 26000, tzinfo=tzlocal())},
#  'ResponseMetadata': {'RequestId': '0957824a-e512-4be2-89f2-4e4d54d2dd05',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Wed, 17 Mar 2021 17:22:03 GMT',
#    'x-amzn-requestid': '0957824a-e512-4be2-89f2-4e4d54d2dd05',
#    'content-length': '263',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %%
response = transcribe_client.get_transcription_job(
    TranscriptionJobName='test-clase-1'
)
response
# Out:
# {'TranscriptionJob': {'TranscriptionJobName': 'test-clase-1',
#   'TranscriptionJobStatus': 'COMPLETED',
#   'LanguageCode': 'es-ES',
#   'MediaSampleRateHertz': 48000,
#   'MediaFormat': 'mp3',
#   'Media': {'MediaFileUri': 's3://sd-test-ml/audios/audio.mp3'},
#   'Transcript': {'TranscriptFileUri': 'https://s3.eu-west-1.amazonaws.com/aws-transcribe-eu-west-1-prod/294604510371/test-clase-1/fadc6ae1-7295-44f1-964e-0ae071398422/asrOutput.json?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCWV1LXdlc3QtMSJIMEYCIQDDyiIMaTCxwBsLs6YZP205uRemqrhrZYSBBngevnVifAIhAKhBJ5Nye29uhXsBe4fp0QHKXujW1Nd9Kyp1lWelDYf0KrQDCDIQAhoMNTg3MDE3NjYzNDE3IgxIINUq4rdl4D%2FWif8qkQMguMO%2FL7zkrjrFt949DGdTbfjIbyIaEKCV4kJO%2BMIN6qwdBqu8VFrVXvHEflJXtrIxirWzj%2F8Uwc%2Fyp10NXBcmGTGzRSZRnmhLrmDbmsa151ErP88DefseqFWLMDODzGLcNbR7KSXYbdU%2B3sCuHS2vqVGioHzGM2rgvz72MEr9XeFmkK0VCxw1zqZ2DJEgnJWlVWr0eewKEkviASQ8Yl6NGoGN0XtslEUkTzBaguFql653sRavjNejjEzPhyslvDFpPb3H%2BQ5MsOdFuWqavev1WPIwm2hADbxe8rNsbxSNnPkuTMGhJvt5R%2F0B58opNw6xsj25sYWJYXGwSvSmY80hZEjIgt2lyD%2B%2F7IKxDqbwpsWnlGB%2FF31UWHUhNAEg52VwCf10onM2pNIDQWO6Vw30Ilvsz94mrEJ%2Bdbo7%2BiMFAkyUwisHT1UejKUbZz3H9HR6O8hojBEQRMalsmG4vUyBZNwjMPzZW566wFL9mOGMhR3gfOj5%2Fhp6WsdtFd1zk6egZyJtCSjvKWkkXQhn8PBkuzCQ3MiCBjrqAeKnil5awduSBsvBlVVc%2Fv360XtBqWKANfzewZ9w7yJdPxA%2FhZyge8k8n9nJe4k52AsYx0ktTtM2OIgjDhtXm%2F5gozsqnQ%2FLwZuRhjxU0IpCVRsOhewFyL8692TqA%2FNY15%2Fj2biVlQ6DFy%2FUBeKDyPWUh0Ybo3ioB2NaqRkEbhP1BCcnCb3gjco6XXzbcqL0FkNIF9xI%2FntWbFDAD0p%2FApckhl1lLGLAQ49ZTpLI8OPNqHDli1nEylFKrezZMmDUr5pTvGOxXSTC8j7JxgsYNK8rpshuphEvUuO7o8Fwdn86ASSF95DgdCHU1Q%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20210317T172224Z&X-Amz-SignedHeaders=host&X-Amz-Expires=900&X-Amz-Credential=ASIAYRLH2WO4UQ5MOAHZ%2F20210317%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Signature=3b9e1638c63ed4b1ea37f4af3c307a0cb9be15af528f1e8840aa9e86d8ee9d8f'},
#   'StartTime': datetime.datetime(2021, 3, 17, 18, 22, 4, 47000, tzinfo=tzlocal()),
#   'CreationTime': datetime.datetime(2021, 3, 17, 18, 22, 4, 26000, tzinfo=tzlocal()),
#   'CompletionTime': datetime.datetime(2021, 3, 17, 18, 22, 24, 14000, tzinfo=tzlocal()),
#   'Settings': {'ChannelIdentification': False, 'ShowAlternatives': False}},
#  'ResponseMetadata': {'RequestId': 'b4efe4de-60ba-4c82-991f-7575fb62e378',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Wed, 17 Mar 2021 17:22:24 GMT',
#    'x-amzn-requestid': 'b4efe4de-60ba-4c82-991f-7575fb62e378',
#    'content-length': '1986',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %%
output = requests.get(response["TranscriptionJob"]["Transcript"]["TranscriptFileUri"]).json()

# %%
output
# Out:
# {'jobName': 'test-clase-1',
#  'accountId': '294604510371',
#  'results': {'transcripts': [{'transcript': 'uno dos tres cuatro cinco seis siete ocho nueve diez once doce trece catorce quince. Vicenti siete ocho ocho nueve. En entre un noventa y dos veintitrés. Veinticuatro veinticinco, veintiséis veintisiete veintiocho veintinueve treinta.'}],
#   'items': [{'start_time': '0.0',
#     'end_time': '0.12',
#     'alternatives': [{'confidence': '0.7208', 'content': 'uno'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.12',
#     'end_time': '0.4',
#     'alternatives': [{'confidence': '0.9988', 'content': 'dos'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.4',
#     'end_time': '0.66',
#     'alternatives': [{'confidence': '1.0', 'content': 'tres'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.66',
#     'end_time': '1.02',
#     'alternatives': [{'confidence': '1.0', 'content': 'cuatro'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.02',
#     'end_time': '1.35',
#     'alternatives': [{'confidence': '1.0', 'content': 'cinco'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.35',
#     'end_time': '1.62',
#     'alternatives': [{'confidence': '1.0', 'content': 'seis'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.62',
#     'end_time': '1.94',
#     'alternatives': [{'confidence': '1.0', 'content': 'siete'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.94',
#     'end_time': '2.2',
#     'alternatives': [{'confidence': '1.0', 'content': 'ocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.2',
#     'end_time': '2.5',
#     'alternatives': [{'confidence': '1.0', 'content': 'nueve'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.5',
#     'end_time': '2.8',
#     'alternatives': [{'confidence': '1.0', 'content': 'diez'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.8',
#     'end_time': '3.06',
#     'alternatives': [{'confidence': '1.0', 'content': 'once'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.06',
#     'end_time': '3.38',
#     'alternatives': [{'confidence': '1.0', 'content': 'doce'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.38',
#     'end_time': '3.68',
#     'alternatives': [{'confidence': '1.0', 'content': 'trece'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.68',
#     'end_time': '4.11',
#     'alternatives': [{'confidence': '1.0', 'content': 'catorce'}],
#     'type': 'pronunciation'},
#    {'start_time': '4.11',
#     'end_time': '4.44',
#     'alternatives': [{'confidence': '1.0', 'content': 'quince'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'},
#    {'start_time': '4.44',
#     'end_time': '4.97',
#     'alternatives': [{'confidence': '1.0', 'content': 'Vicenti'}],
#     'type': 'pronunciation'},
#    {'start_time': '4.97',
#     'end_time': '5.37',
#     'alternatives': [{'confidence': '1.0', 'content': 'siete'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.38',
#     'end_time': '5.55',
#     'alternatives': [{'confidence': '0.7719', 'content': 'ocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.55',
#     'end_time': '5.78',
#     'alternatives': [{'confidence': '0.7724', 'content': 'ocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.78',
#     'end_time': '6.14',
#     'alternatives': [{'confidence': '0.6311', 'content': 'nueve'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'},
#    {'start_time': '6.14',
#     'end_time': '6.35',
#     'alternatives': [{'confidence': '0.1878', 'content': 'En'}],
#     'type': 'pronunciation'},
#    {'start_time': '6.74',
#     'end_time': '7.06',
#     'alternatives': [{'confidence': '0.4942', 'content': 'entre'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.06',
#     'end_time': '7.12',
#     'alternatives': [{'confidence': '0.6903', 'content': 'un'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.12',
#     'end_time': '7.42',
#     'alternatives': [{'confidence': '1.0', 'content': 'noventa'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.42',
#     'end_time': '7.46',
#     'alternatives': [{'confidence': '1.0', 'content': 'y'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.46',
#     'end_time': '7.63',
#     'alternatives': [{'confidence': '1.0', 'content': 'dos'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.63',
#     'end_time': '8.17',
#     'alternatives': [{'confidence': '1.0', 'content': 'veintitrés'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'},
#    {'start_time': '8.17',
#     'end_time': '8.65',
#     'alternatives': [{'confidence': '1.0', 'content': 'Veinticuatro'}],
#     'type': 'pronunciation'},
#    {'start_time': '8.65',
#     'end_time': '9.08',
#     'alternatives': [{'confidence': '0.9452', 'content': 'veinticinco'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': ','}],
#     'type': 'punctuation'},
#    {'start_time': '9.08',
#     'end_time': '9.54',
#     'alternatives': [{'confidence': '0.9447', 'content': 'veintiséis'}],
#     'type': 'pronunciation'},
#    {'start_time': '9.54',
#     'end_time': '10.05',
#     'alternatives': [{'confidence': '0.9348', 'content': 'veintisiete'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.05',
#     'end_time': '10.51',
#     'alternatives': [{'confidence': '1.0', 'content': 'veintiocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.51',
#     'end_time': '10.98',
#     'alternatives': [{'confidence': '0.8784', 'content': 'veintinueve'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.98',
#     'end_time': '11.85',
#     'alternatives': [{'confidence': '1.0', 'content': 'treinta'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'}]},
#  'status': 'COMPLETED'}

# %% [markdown]
# ### Creating a filter vocabulary

# %%
response = transcribe_client.create_vocabulary_filter(
    VocabularyFilterName='numbers',
    LanguageCode='es-ES',
    Words=[
        'uno','siete','diez','treinta'
    ]
)

# %%
response = transcribe_client.start_transcription_job(
    TranscriptionJobName='test-clase-2',
    LanguageCode='es-ES',
    MediaFormat='mp3',
    Media={
        'MediaFileUri': f"s3://sd-test-ml/audios/audio.mp3"
    },
    Settings={
#        'ShowAlternatives': True,
#        'MaxAlternatives': 3,
        'VocabularyFilterName': 'numbers',
#        'VocabularyFilterMethod': 'remove'|'mask'
    },
)

# %%
# %timeit
response = {
    'TranscriptionJob': {
      'TranscriptionJobStatus': ''
    }
}

while response['TranscriptionJob']['TranscriptionJobStatus'] != 'COMPLETED':
    time.sleep(1)
    response = transcribe_client.get_transcription_job(
        TranscriptionJobName='test-clase-2'
    )
    print(response['TranscriptionJob']['TranscriptionJobStatus'])
# Out:
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# COMPLETED

# %%
response
# Out:
# {'TranscriptionJob': {'TranscriptionJobName': 'test-clase-2',
#   'TranscriptionJobStatus': 'COMPLETED',
#   'LanguageCode': 'es-ES',
#   'MediaSampleRateHertz': 48000,
#   'MediaFormat': 'mp3',
#   'Media': {'MediaFileUri': 's3://sd-test-ml/audios/audio.mp3'},
#   'Transcript': {'TranscriptFileUri': 'https://s3.eu-west-1.amazonaws.com/aws-transcribe-eu-west-1-prod/294604510371/test-clase-2/52869a72-a64c-4737-9b66-1fe9ac6fc4ca/asrOutput.json?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCWV1LXdlc3QtMSJHMEUCIQCHhI97bQonqrR3C9%2BHQE%2F5tXQ%2FiBticrVBZbYca%2F7BZgIgF8KSHanRa9y9lYW%2BsoKzjHXX4nmO70YnNw8jnzdKN5QqtAMIMhACGgw1ODcwMTc2NjM0MTciDEjkeEXBCJXz6VDaXCqRAw5TRmzSbcLBPL6PT6ur4aqjRpvsLrQILZOhfBTmbl0m4OXIlAzHtgZKbaCRS9E3NeL4Uzx3cYGzOch2UB%2F0EgJRTtLIkAF1uNDAK4ekmnlGraSW%2FeQet9acKX7QDTvOp%2FWXkmzE6Fo3K2RcNu6AV%2FyYq1iERVdLlUAPIr63TpbiZ%2FS3DQL%2B20tgR9yZe5sNt2evL3sl4qs4I2QVjWmyOIlQoSlpatBDgr%2BIR%2B%2Fqwlrs%2FGs5zuY3d92RskZwiOteOkJIeMnTKabkEad1u84oFUcn3sxTw6vTkOXMGWYhYG29DGWu2S0qG3ljRN9U7jAM70kNCDYvQyREBaH%2FKiQA3MKryXwt1iD4pzAlzoeyx2%2FMFNMZ5%2F6GTOX3AnM2pXjwdXeFIIf7pB1l0rhIVuuzw92oWB%2FW2Oa%2B3%2FVLPELdcOHE%2F5Fz4ikV0oTmzZVxaSW0qPP9Du9V%2FaBpkRpOhEEL3W8SjGOM88gbx7cHqPd%2BdF%2B9PmlVxs9aiVFkBzbbcZVPUQz%2Bb3CUKB94YkdyFsMoXnr8MJLgyIIGOusB29brPPEJvB7ywIFYnSn1LJn9u2Uf%2BAcq1YQO9MHsPHBAhtqZx0GT33u3umNTL9VuixgEQu0sk7G0a6YKw2yID9OPGzCquWGjW%2FSgrTE5Ot9%2B9sn%2FBEV6jfk6Nmx0%2BppMNmgEoPmRTG9XgpE4oAf71SaSnowFTjav1T6muRWDWmgubtZnY5fVfTTkRYDkEORtWnzXRIMIMdfPELPgQd%2BEjfSsI8M08sR8K0h7X8A3%2BsNh2hvJoAkr7rct3M2E4qTQH3QEHSn0Hc9tvz1ehfvTWFpTruBTDWxct0lWglzUrelCv32aCNBEawavuw%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20210317T172757Z&X-Amz-SignedHeaders=host&X-Amz-Expires=900&X-Amz-Credential=ASIAYRLH2WO4SDEXIYXM%2F20210317%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Signature=661b6a7e5a72040728930e01af78fa6f07e93ad1ee979e4f2192fe18569c9c74'},
#   'StartTime': datetime.datetime(2021, 3, 17, 18, 27, 38, 623000, tzinfo=tzlocal()),
#   'CreationTime': datetime.datetime(2021, 3, 17, 18, 27, 38, 599000, tzinfo=tzlocal()),
#   'CompletionTime': datetime.datetime(2021, 3, 17, 18, 27, 56, 407000, tzinfo=tzlocal()),
#   'Settings': {'ChannelIdentification': False,
#    'ShowAlternatives': False,
#    'VocabularyFilterName': 'numbers'}},
#  'ResponseMetadata': {'RequestId': '44b4506b-3beb-45b9-992e-f17943a34cfb',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Wed, 17 Mar 2021 17:27:56 GMT',
#    'x-amzn-requestid': '44b4506b-3beb-45b9-992e-f17943a34cfb',
#    'content-length': '2039',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %%
output = requests.get(response["TranscriptionJob"]["Transcript"]["TranscriptFileUri"]).json()

# %%
output
# Out:
# {'jobName': 'test-clase-2',
#  'accountId': '294604510371',
#  'results': {'transcripts': [{'transcript': '*** dos tres cuatro cinco seis *** ocho nueve *** once doce trece catorce quince. Vicenti *** ocho ocho nueve. En entre un noventa y dos veintitrés. Veinticuatro veinticinco, veintiséis veintisiete veintiocho veintinueve ***.'}],
#   'items': [{'start_time': '0.0',
#     'end_time': '0.12',
#     'alternatives': [{'confidence': '0.7208', 'content': '***'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.12',
#     'end_time': '0.4',
#     'alternatives': [{'confidence': '0.9988', 'content': 'dos'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.4',
#     'end_time': '0.66',
#     'alternatives': [{'confidence': '1.0', 'content': 'tres'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.66',
#     'end_time': '1.02',
#     'alternatives': [{'confidence': '1.0', 'content': 'cuatro'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.02',
#     'end_time': '1.35',
#     'alternatives': [{'confidence': '1.0', 'content': 'cinco'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.35',
#     'end_time': '1.62',
#     'alternatives': [{'confidence': '1.0', 'content': 'seis'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.62',
#     'end_time': '1.94',
#     'alternatives': [{'confidence': '1.0', 'content': '***'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.94',
#     'end_time': '2.2',
#     'alternatives': [{'confidence': '1.0', 'content': 'ocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.2',
#     'end_time': '2.5',
#     'alternatives': [{'confidence': '1.0', 'content': 'nueve'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.5',
#     'end_time': '2.8',
#     'alternatives': [{'confidence': '1.0', 'content': '***'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.8',
#     'end_time': '3.06',
#     'alternatives': [{'confidence': '1.0', 'content': 'once'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.06',
#     'end_time': '3.38',
#     'alternatives': [{'confidence': '1.0', 'content': 'doce'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.38',
#     'end_time': '3.68',
#     'alternatives': [{'confidence': '1.0', 'content': 'trece'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.68',
#     'end_time': '4.11',
#     'alternatives': [{'confidence': '1.0', 'content': 'catorce'}],
#     'type': 'pronunciation'},
#    {'start_time': '4.11',
#     'end_time': '4.44',
#     'alternatives': [{'confidence': '1.0', 'content': 'quince'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'},
#    {'start_time': '4.44',
#     'end_time': '4.97',
#     'alternatives': [{'confidence': '1.0', 'content': 'Vicenti'}],
#     'type': 'pronunciation'},
#    {'start_time': '4.97',
#     'end_time': '5.37',
#     'alternatives': [{'confidence': '1.0', 'content': '***'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.38',
#     'end_time': '5.55',
#     'alternatives': [{'confidence': '0.7719', 'content': 'ocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.55',
#     'end_time': '5.78',
#     'alternatives': [{'confidence': '0.7724', 'content': 'ocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.78',
#     'end_time': '6.14',
#     'alternatives': [{'confidence': '0.6311', 'content': 'nueve'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'},
#    {'start_time': '6.14',
#     'end_time': '6.35',
#     'alternatives': [{'confidence': '0.1878', 'content': 'En'}],
#     'type': 'pronunciation'},
#    {'start_time': '6.74',
#     'end_time': '7.06',
#     'alternatives': [{'confidence': '0.4942', 'content': 'entre'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.06',
#     'end_time': '7.12',
#     'alternatives': [{'confidence': '0.6903', 'content': 'un'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.12',
#     'end_time': '7.42',
#     'alternatives': [{'confidence': '1.0', 'content': 'noventa'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.42',
#     'end_time': '7.46',
#     'alternatives': [{'confidence': '1.0', 'content': 'y'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.46',
#     'end_time': '7.63',
#     'alternatives': [{'confidence': '1.0', 'content': 'dos'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.63',
#     'end_time': '8.17',
#     'alternatives': [{'confidence': '1.0', 'content': 'veintitrés'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'},
#    {'start_time': '8.17',
#     'end_time': '8.65',
#     'alternatives': [{'confidence': '1.0', 'content': 'Veinticuatro'}],
#     'type': 'pronunciation'},
#    {'start_time': '8.65',
#     'end_time': '9.08',
#     'alternatives': [{'confidence': '0.9452', 'content': 'veinticinco'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': ','}],
#     'type': 'punctuation'},
#    {'start_time': '9.08',
#     'end_time': '9.54',
#     'alternatives': [{'confidence': '0.9447', 'content': 'veintiséis'}],
#     'type': 'pronunciation'},
#    {'start_time': '9.54',
#     'end_time': '10.05',
#     'alternatives': [{'confidence': '0.9348', 'content': 'veintisiete'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.05',
#     'end_time': '10.51',
#     'alternatives': [{'confidence': '1.0', 'content': 'veintiocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.51',
#     'end_time': '10.98',
#     'alternatives': [{'confidence': '0.8784', 'content': 'veintinueve'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.98',
#     'end_time': '11.85',
#     'alternatives': [{'confidence': '1.0', 'content': '***'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'}]},
#  'status': 'COMPLETED'}

# %% [markdown]
# ### Creating vocabulary

# %%
response = transcribe_client.create_vocabulary(
    VocabularyName='numbers',
    LanguageCode='es-ES',
    Phrases=[
        'uno',
        'siete',
        'diez',
        'treinta'
    ]
)

# %%
response = transcribe_client.start_transcription_job(
    TranscriptionJobName='test-clase-3',
    LanguageCode='es-ES',
    MediaFormat='mp3',
    Media={
        'MediaFileUri': f"s3://sd-test-ml/audios/audio.mp3"
    },
    Settings={
        'VocabularyName': 'numbers'
    }
)

# %%
response = {
    'TranscriptionJob': {
      'TranscriptionJobStatus': ''
    }
}

while response['TranscriptionJob']['TranscriptionJobStatus'] != 'COMPLETED':
    time.sleep(1)
    response = transcribe_client.get_transcription_job(
        TranscriptionJobName='test-clase-3'
    )
    print(response['TranscriptionJob']['TranscriptionJobStatus'])
# Out:
# COMPLETED

# %%
response
# Out:
# {'TranscriptionJob': {'TranscriptionJobName': 'test-clase-3',
#   'TranscriptionJobStatus': 'COMPLETED',
#   'LanguageCode': 'es-ES',
#   'MediaSampleRateHertz': 48000,
#   'MediaFormat': 'mp3',
#   'Media': {'MediaFileUri': 's3://sd-test-ml/audios/audio.mp3'},
#   'Transcript': {'TranscriptFileUri': 'https://s3.eu-west-1.amazonaws.com/aws-transcribe-eu-west-1-prod/294604510371/test-clase-3/abb85346-67bf-4ce0-a55d-140e1235db40/asrOutput.json?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPr%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCWV1LXdlc3QtMSJHMEUCIQCZS0d4ZPgIiUed1gfuv%2BTomW1owneYIvz%2BVxsZlRYnagIgVvip3hmfeTBftfNRhoPJTElTXCk8Gl0PGbU6FnsF0IAqtAMIMhACGgw1ODcwMTc2NjM0MTciDCShaUSVSplQnowvXSqRA7wMLjYmZujrOQmmOi5uVgzISNLQXO7Iu5oTTQJodM%2B2xmVeb7hHIKlTwISf%2FvGh1V1Ulk%2Bz90k9AhKtmTmyjHLuIhRv39tdcQZqppszHm9Kmo1NtTVXv1KvGHBO20EL3GxqgLlUalT0LgNY7FTj8VJnaFJJuVT2Om2EiSwfL92pB71Cd7m90Ue%2BIGGZHDA0tQpY54wTXilKw9ItHgOaFRkOvbcae%2FcVe8%2FFdahYUhnxY1%2FpCHP7l1CaJKoWuYhaYNv9cDRY4tYALSxDRF7cvGCzGIYQsVlg7McKt5zqKE8JI08lXL7%2FJLcKHkNz7UbxEZ%2Bt1r11fSm8%2FTlAJRRlBkMGajhMewxD8KFsFONxUb%2Bw99aQbljolFm4XX6Sc3w%2FbZEexyHF6vcc3x1BB2jJH0l4u3s98xSH%2FiVFizoDD%2FDaWCHVOfZXA9ufaQ1GsC%2Fk1467FQZD0gfxcdeNtxXm8oBTtqiMbqXYl3lZEdUiobsfUZHb1GG1Q%2B%2BJHXFg677Fa0FxUq2r0QhzxL4xEGqUP9%2FKMKDxyIIGOusBEvFtdTOuH6KvmqlaM8PfoMW7RjoAMT8akZut5BJcifI%2F9SaK8oIe%2FLufAh4QffQbwaqYT5uR803M5Wk88yd8IhiDE9RrQ84YcDAI3JGnm0DalJV%2F1sOZ%2FFO4L7%2B95dwYAffNdgBnfR16qMco6RkAOhc%2FqOFD5wucyUC7NvOkglvZmy6BCB8YKROjQCyfEmD6I6Dq75rL6Wcsi4jFKtvD0E8p6xoM%2Fa6wCBML%2FHv7Pn1BH%2FrK9BExovKAjCvHOKQZYD3XQbFFxAelWDbHe%2Fm9UJwIDd3Tu2FFbhheth717C%2BfaoBEmL8ZFX%2F7DA%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20210317T173336Z&X-Amz-SignedHeaders=host&X-Amz-Expires=900&X-Amz-Credential=ASIAYRLH2WO42JYVUQS7%2F20210317%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Signature=54986c1ca3b584e6e9dee17f45974c3328a03e7c2dd92190a9b9f5dd5f4170a4'},
#   'StartTime': datetime.datetime(2021, 3, 17, 18, 32, 28, 454000, tzinfo=tzlocal()),
#   'CreationTime': datetime.datetime(2021, 3, 17, 18, 32, 28, 424000, tzinfo=tzlocal()),
#   'CompletionTime': datetime.datetime(2021, 3, 17, 18, 32, 48, 62000, tzinfo=tzlocal()),
#   'Settings': {'VocabularyName': 'numbers',
#    'ChannelIdentification': False,
#    'ShowAlternatives': False}},
#  'ResponseMetadata': {'RequestId': 'eddb71bf-f974-4139-bfb6-319794c242e4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Wed, 17 Mar 2021 17:33:36 GMT',
#    'x-amzn-requestid': 'eddb71bf-f974-4139-bfb6-319794c242e4',
#    'content-length': '2031',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %%
output = requests.get(response["TranscriptionJob"]["Transcript"]["TranscriptFileUri"]).json()

# %%
output
# Out:
# {'jobName': 'test-clase-3',
#  'accountId': '294604510371',
#  'results': {'transcripts': [{'transcript': 'uno dos, tres cuatro cinco, seis siete, ocho nueve, diez once, doce trece catorce quince Vicenti siete chochona deben entre un noventa y dos veintitrés veinticuatro y cinco mil seis siete veintiocho mil nueve treinta.'}],
#   'items': [{'start_time': '0.0',
#     'end_time': '0.12',
#     'alternatives': [{'confidence': '0.7161', 'content': 'uno'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.12',
#     'end_time': '0.4',
#     'alternatives': [{'confidence': '0.9989', 'content': 'dos'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': ','}],
#     'type': 'punctuation'},
#    {'start_time': '0.4',
#     'end_time': '0.66',
#     'alternatives': [{'confidence': '1.0', 'content': 'tres'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.66',
#     'end_time': '1.02',
#     'alternatives': [{'confidence': '1.0', 'content': 'cuatro'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.02',
#     'end_time': '1.35',
#     'alternatives': [{'confidence': '1.0', 'content': 'cinco'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': ','}],
#     'type': 'punctuation'},
#    {'start_time': '1.35',
#     'end_time': '1.62',
#     'alternatives': [{'confidence': '1.0', 'content': 'seis'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.62',
#     'end_time': '1.94',
#     'alternatives': [{'confidence': '1.0', 'content': 'siete'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': ','}],
#     'type': 'punctuation'},
#    {'start_time': '1.94',
#     'end_time': '2.2',
#     'alternatives': [{'confidence': '1.0', 'content': 'ocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.2',
#     'end_time': '2.5',
#     'alternatives': [{'confidence': '1.0', 'content': 'nueve'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': ','}],
#     'type': 'punctuation'},
#    {'start_time': '2.5',
#     'end_time': '2.8',
#     'alternatives': [{'confidence': '1.0', 'content': 'diez'}],
#     'type': 'pronunciation'},
#    {'start_time': '2.8',
#     'end_time': '3.06',
#     'alternatives': [{'confidence': '1.0', 'content': 'once'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': ','}],
#     'type': 'punctuation'},
#    {'start_time': '3.06',
#     'end_time': '3.38',
#     'alternatives': [{'confidence': '1.0', 'content': 'doce'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.38',
#     'end_time': '3.68',
#     'alternatives': [{'confidence': '1.0', 'content': 'trece'}],
#     'type': 'pronunciation'},
#    {'start_time': '3.68',
#     'end_time': '4.11',
#     'alternatives': [{'confidence': '1.0', 'content': 'catorce'}],
#     'type': 'pronunciation'},
#    {'start_time': '4.11',
#     'end_time': '4.44',
#     'alternatives': [{'confidence': '1.0', 'content': 'quince'}],
#     'type': 'pronunciation'},
#    {'start_time': '4.44',
#     'end_time': '4.97',
#     'alternatives': [{'confidence': '0.9928', 'content': 'Vicenti'}],
#     'type': 'pronunciation'},
#    {'start_time': '4.97',
#     'end_time': '5.39',
#     'alternatives': [{'confidence': '0.9', 'content': 'siete'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.39',
#     'end_time': '5.94',
#     'alternatives': [{'confidence': '0.8459', 'content': 'chochona'}],
#     'type': 'pronunciation'},
#    {'start_time': '5.94',
#     'end_time': '6.35',
#     'alternatives': [{'confidence': '0.2896', 'content': 'deben'}],
#     'type': 'pronunciation'},
#    {'start_time': '6.74',
#     'end_time': '7.06',
#     'alternatives': [{'confidence': '0.512', 'content': 'entre'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.06',
#     'end_time': '7.12',
#     'alternatives': [{'confidence': '0.7188', 'content': 'un'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.12',
#     'end_time': '7.42',
#     'alternatives': [{'confidence': '1.0', 'content': 'noventa'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.42',
#     'end_time': '7.46',
#     'alternatives': [{'confidence': '1.0', 'content': 'y'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.46',
#     'end_time': '7.63',
#     'alternatives': [{'confidence': '1.0', 'content': 'dos'}],
#     'type': 'pronunciation'},
#    {'start_time': '7.63',
#     'end_time': '8.17',
#     'alternatives': [{'confidence': '1.0', 'content': 'veintitrés'}],
#     'type': 'pronunciation'},
#    {'start_time': '8.17',
#     'end_time': '8.73',
#     'alternatives': [{'confidence': '1.0', 'content': 'veinticuatro'}],
#     'type': 'pronunciation'},
#    {'start_time': '8.73',
#     'end_time': '8.8',
#     'alternatives': [{'confidence': '0.5898', 'content': 'y'}],
#     'type': 'pronunciation'},
#    {'start_time': '8.8',
#     'end_time': '9.08',
#     'alternatives': [{'confidence': '0.9509', 'content': 'cinco'}],
#     'type': 'pronunciation'},
#    {'start_time': '9.08',
#     'end_time': '9.29',
#     'alternatives': [{'confidence': '0.5205', 'content': 'mil'}],
#     'type': 'pronunciation'},
#    {'start_time': '9.29',
#     'end_time': '9.56',
#     'alternatives': [{'confidence': '0.9177', 'content': 'seis'}],
#     'type': 'pronunciation'},
#    {'start_time': '9.57',
#     'end_time': '10.05',
#     'alternatives': [{'confidence': '0.8715', 'content': 'siete'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.05',
#     'end_time': '10.61',
#     'alternatives': [{'confidence': '1.0', 'content': 'veintiocho'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.62',
#     'end_time': '10.76',
#     'alternatives': [{'confidence': '0.4738', 'content': 'mil'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.76',
#     'end_time': '10.98',
#     'alternatives': [{'confidence': '0.4488', 'content': 'nueve'}],
#     'type': 'pronunciation'},
#    {'start_time': '10.98',
#     'end_time': '11.85',
#     'alternatives': [{'confidence': '0.9925', 'content': 'treinta'}],
#     'type': 'pronunciation'},
#    {'alternatives': [{'confidence': '0.0', 'content': '.'}],
#     'type': 'punctuation'}]},
#  'status': 'COMPLETED'}

# %% [markdown]
# ### Process multiple audios

# %%
result = {}

for record in data[:20]:  

    audio_id = record['id'].split('/')[-1][20:]
    response = transcribe_client.start_transcription_job(
        TranscriptionJobName=audio_id,
        LanguageCode='es-ES',
        MediaFormat='mp3',
        Media={
            'MediaFileUri': record['audio']['s3'].replace('sources', 'processed/sources')
        }
    )
    
    response = {
        'TranscriptionJob': {
          'TranscriptionJobStatus': ''
        }
    }
    
    start = time.time()
    while response['TranscriptionJob']['TranscriptionJobStatus'] != 'COMPLETED':
        time.sleep(1)
        response = transcribe_client.get_transcription_job(
            TranscriptionJobName=audio_id
        )
        
    end = time.time()
    print(f"Time spent: {end-start}")
    
    output = requests.get(response["TranscriptionJob"]["Transcript"]["TranscriptFileUri"]).json()    
    
    result[audio_id] = {
        '1': 'uno' in output['results']['transcripts'][0]['transcript'],
        '7': 'siete' in output['results']['transcripts'][0]['transcript'],
        '10': 'diez' in output['results']['transcripts'][0]['transcript'],
        '30': 'treinta' in output['results']['transcripts'][0]['transcript']
    }
# Out:
# Time spent: 32.20404410362244
# Time spent: 28.949074268341064
# Time spent: 22.17820906639099
# Time spent: 19.99015522003174
# Time spent: 52.77833700180054
# Time spent: 22.20543909072876
# Time spent: 27.76417875289917
# Time spent: 23.18256711959839
# Time spent: 63.23955821990967
# Time spent: 33.46356415748596
# Time spent: 18.939187049865723
# Time spent: 19.890972137451172
# Time spent: 19.918843984603882
# Time spent: 30.911147117614746
# Time spent: 20.557868719100952
# Time spent: 17.68913722038269
# Time spent: 27.638123750686646
# Time spent: 17.916567087173462
# Time spent: 17.758325815200806
# Time spent: 26.62440299987793

# %%
result
# Out:
# {'806145f6-ebae-43e3-848f-3d6b26d803bd': {'1': True,
#   '7': True,
#   '10': False,
#   '30': False},
#  'd866b2c0-6eca-40e1-ad93-5f4feab08421': {'1': True,
#   '7': True,
#   '10': False,
#   '30': False},
#  '39f1a1db-904a-4069-9a35-005847b9101c': {'1': True,
#   '7': True,
#   '10': True,
#   '30': False},
#  '109d0932-6702-4390-9e4c-d01177e1fb5c': {'1': False,
#   '7': False,
#   '10': False,
#   '30': False},
#  '7e43bff4-5cec-48e2-8697-1e72f81a8522': {'1': True,
#   '7': True,
#   '10': False,
#   '30': False},
#  '26e43698-7653-46eb-9ba4-e3a4502db126': {'1': True,
#   '7': True,
#   '10': True,
#   '30': False},
#  'c453e481-e0cc-4509-b321-f8dce76be00a': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  'ab9362e1-e884-4648-86a4-d22e9cb0acf5': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  'fc67332b-fb3f-401b-a506-dd13e0bb3a35': {'1': False,
#   '7': True,
#   '10': False,
#   '30': False},
#  'e08b689e-100e-437f-9f33-559ff3436567': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  '976e8c69-7daa-4a54-9f65-aac75dd06161': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  '34ae78bd-fdb2-4e8b-898d-a9d8de973fce': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  'f9295b32-8440-413b-b276-47f8a7d5932a': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  '25454325-9ab0-49de-86b2-03d8917d028f': {'1': False,
#   '7': True,
#   '10': False,
#   '30': False},
#  'a7a7daaa-03ae-4233-887f-1b1d5445b477': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  '6224035c-741c-4216-a777-79e6e6243224': {'1': True,
#   '7': True,
#   '10': True,
#   '30': False},
#  '2f78e3ed-599e-4b9d-b519-11a234970dbb': {'1': False,
#   '7': True,
#   '10': True,
#   '30': True},
#  'c509b98d-71db-48ba-81bc-971bd01d9089': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  '3abe4f55-12d6-49e8-b469-c010e67dd60b': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True},
#  '745b61ff-3200-4d43-bf01-88d4cdac8656': {'1': True,
#   '7': True,
#   '10': True,
#   '30': True}}

# %%
df = pd.DataFrame.from_dict(result, orient='index')

# %%
df
# Out:
#                                           1      7     10     30
# 806145f6-ebae-43e3-848f-3d6b26d803bd   True   True  False  False
# d866b2c0-6eca-40e1-ad93-5f4feab08421   True   True  False  False
# 39f1a1db-904a-4069-9a35-005847b9101c   True   True   True  False
# 109d0932-6702-4390-9e4c-d01177e1fb5c  False  False  False  False
# 7e43bff4-5cec-48e2-8697-1e72f81a8522   True   True  False  False
# 26e43698-7653-46eb-9ba4-e3a4502db126   True   True   True  False
# c453e481-e0cc-4509-b321-f8dce76be00a   True   True   True   True
# ab9362e1-e884-4648-86a4-d22e9cb0acf5   True   True   True   True
# fc67332b-fb3f-401b-a506-dd13e0bb3a35  False   True  False  False
# e08b689e-100e-437f-9f33-559ff3436567   True   True   True   True
# 976e8c69-7daa-4a54-9f65-aac75dd06161   True   True   True   True
# 34ae78bd-fdb2-4e8b-898d-a9d8de973fce   True   True   True   True
# f9295b32-8440-413b-b276-47f8a7d5932a   True   True   True   True
# 25454325-9ab0-49de-86b2-03d8917d028f  False   True  False  False
# a7a7daaa-03ae-4233-887f-1b1d5445b477   True   True   True   True
# 6224035c-741c-4216-a777-79e6e6243224   True   True   True  False
# 2f78e3ed-599e-4b9d-b519-11a234970dbb  False   True   True   True
# c509b98d-71db-48ba-81bc-971bd01d9089   True   True   True   True
# 3abe4f55-12d6-49e8-b469-c010e67dd60b   True   True   True   True
# 745b61ff-3200-4d43-bf01-88d4cdac8656   True   True   True   True
