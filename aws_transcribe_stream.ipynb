# %%
# !python -m pip install amazon-transcribe aiofile
# Out:
# ...
#      |████████████████████████████████| 365 kB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 43 kB 2.9 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/dmedina/workspace/demosense/smart-dyspnea/smart-dyspnea-ml/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# Creating a client for Transcribe Streaming

# %%
import aiofile

# %%
result = []
async with aiofile.AIOFile('data/test.wav', 'rb') as afp:
    reader = aiofile.Reader(afp, chunk_size=1024 * 16)
    async for chunk in reader:
        result.append(chunk)

# %%
len(result[0])
# Out:
# 16384

# %%
with open('data/test.wav', 'rb') as f:
    audio = f.read()

# %%
for i in range(0,len(audio), 1024 * 16):
    print(len(audio[i:i+(1024 * 16)]))
# Out:
# 16384
# 16384
# 8144

# %%
import io
import json
import base64

with open('./data/ml_data.json', 'r') as f:
    data = json.loads(f.read())

audio = base64.b64decode(data[76]['audio']['data'].encode('utf-8'))

a = io.BytesIO(audio)
x = AudioSegment.from_file(a)
y = x.export('data/audio-test.wav', format='wav')

# %%
with open('data/audio-test.wav', 'rb') as f:
    audio2 = f.read()

# %%
audio2[:40]
# Out:
# b'RIFF$\x80#\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x02\x00\x80\xbb\x00\x00\x00\xee\x02\x00\x04\x00\x10\x00data'

# %%
audio[:40]
# Out:
# b'ID3\x04\x00\x00\x00\x00\x00#TSSE\x00\x00\x00\x0f\x00\x00\x03Lavf58.45.100\x00\x00\x00\x00\x00\x00'

# %%
from os import path
from pydub import AudioSegment

# files                                                                         
src = "data/audio2.mp3"
dst = "data/test2.wav"

# convert wav to mp3                                                            
sound = AudioSegment.from_mp3(src)
sound.export(dst, format="wav")
# Out:
# <_io.BufferedRandom name='data/test2.wav'>
